# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a52365/AIML_2303a52365/blob/main/AIML_ASS_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Part 1 – Implement Basic Data Structures using Numpy, Pandas
# 1. Lists
# 2. Arrays
# 3. Identify their type using type()
# 4. Perform mathematical operations on these datasets created - multiplication, division, poweroff
# 5. Combine text with Numpy fuction to generate a textual output - ”Addition of Two: array1 +array 2
# 6. Implement np.sin(), log(), log2(), np.exp())

# %%
import numpy as np
list1=[1,2,3]
list2=[4,5,6]
array1=np.array(list1)
array1
array2=np.array(list2)
array2
# Out:
# array([4, 5, 6])

# %%
type(list1)
# Out:
# list

# %%
type(array1)
# Out:
# numpy.ndarray

# %%
print("array2 Multiplied by array1: ",array1*array2)
# Out:
# array2 Multiplied by array1:  [ 4 10 18]

# %%
print("array2 Divided by array 1: ",array1/array2)
# Out:
# array2 Divided by array 1:  [0.25 0.4  0.5 ]

# %%
print("array2 is raised to the power of array1: ",array1**array2)
# Out:
# array2 is raised to the power of array1:  [  1  32 729]

# %%
print("adding of two nympy arrays {array1} and {array2}:",array1+array2)
# Out:
# adding of two nympy arrays {array1} and {array2}: [5 7 9]

# %%
print("Sine: ",np.sin(array1))
print("Sine: ",np.sin(array2))
# Out:
# Sine:  [0.84147098 0.90929743 0.14112001]
# Sine:  [-0.7568025  -0.95892427 -0.2794155 ]

# %%
print("Sine: ",np.sin(array1))
print("Sine: ",np.sin(array2))
# Out:
# Sine:  [0.84147098 0.90929743 0.14112001]
# Sine:  [-0.7568025  -0.95892427 -0.2794155 ]

# %%
print("log2: ",np.log2(array1))
print("log2: ",np.log2(array2))
# Out:
# log2:  [0.        1.        1.5849625]
# log2:  [2.         2.32192809 2.5849625 ]

# %%
print("exp: ",np.exp(array1))
print("exp: ",np.exp(array2))
# Out:
# exp:  [ 2.71828183  7.3890561  20.08553692]
# exp:  [ 54.59815003 148.4131591  403.42879349]

# %% [markdown]
# Part-02: Lab Task is to visualize the datasets or data using Matplotlib builtin function Graphs Generate Scatterplot Let's suppose we
# collected age (in years), height (in cm), and weight (in kilograms) information from few patients visitng a clinic

# %%
people = ['kiran','arun','vijay','varun']
age = [25,30,35,40]
weight = [145,151,165,173]
height = [45,55,65,75]
import matplotlib.pyplot as plt
plt.scatter(weight, height)
plt.title("Relationship between Weight and Height of Patients")
plt.ylabel("Height in Meters")
plt.xlabel("Weight of Patients in Kgs")
plt.show()

# %% [markdown]
# Generate Bar Plot

# %%
plt.figure(figsize=(12,4))
plt.title("People's weight in kgs",fontsize=16,
fontstyle='italic')
# Main plot function 'bar'
plt.bar(x=people,height=weight, width=0.6,
color='lightblue',edgecolor='k',alpha=0.6)
plt.xlabel("People",fontsize=15)
plt.xticks(fontsize=14,rotation=30)
plt.yticks(fontsize=14)
plt.ylabel("Weight (in kgs)",fontsize=15)
plt.show()

# %% [markdown]
# Generate Histogram

# %%
import numpy as np
plt.figure(figsize=(7,5))
# Main plot function 'hist'
plt.hist(weight,color='black',edgecolor='k', alpha=0.75,bins=5)
plt.title("Histogram of patient weight",fontsize=18)
plt.xlabel("Weight in kgs",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()
